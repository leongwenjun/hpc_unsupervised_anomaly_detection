# %%
import matplotlib.pyplot as plt
import numpy as np

models = ['Autoencoder', 'KMeans', 'iForest']
accuracy = [95, 75, 97]
precision = [17, 6, 54]
recall = [17, 55, 53]
f1_score = [17, 11, 53]
roc_auc = [0.5716, 0.6530, 0.7571]

bar_width = 0.12
r1 = np.arange(len(models))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]
r5 = [x + bar_width for x in r4]

plt.figure(figsize=(15,7))

colors = ['

bars1 = plt.bar(r1, np.array(accuracy)/100, width=bar_width, color=colors[0], edgecolor='grey', label='Accuracy')
bars2 = plt.bar(r2, np.array(precision)/100, width=bar_width, color=colors[1], edgecolor='grey', label='Precision')
bars3 = plt.bar(r3, np.array(recall)/100, width=bar_width, color=colors[2], edgecolor='grey', label='Recall')
bars4 = plt.bar(r4, np.array(f1_score)/100, width=bar_width, color=colors[3], edgecolor='grey', label='F1-Score')
bars5 = plt.bar(r5, roc_auc, width=bar_width, color=colors[4], edgecolor='grey', label='ROC AUC')

plt.xlabel('Models', fontweight='bold', fontsize=15)
plt.ylabel('Metrics (as fractions)', fontweight='bold', fontsize=15)
plt.xticks([r + 2*bar_width for r in range(len(accuracy))], models)

plt.legend(loc='upper right')

plt.tight_layout()
plt.savefig("experiment2_results.pdf")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

models = ['iForest', 'KMeans', 'Autoencoder', 'LSTM Autoencoder']
accuracy = np.array([37, 82, 74, 82]) / 100
precision = np.array([35, 79, 62, 74]) / 100
recall = np.array([100, 65, 60, 72]) / 100
f1_score = np.array([52, 72, 61, 73]) / 100
roc_auc = np.array([0.5197, 0.7821, 0.7058, 0.7951])

bar_width = 0.15
r1 = np.arange(len(models))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]
r5 = [x + bar_width for x in r4]

plt.figure(figsize=(15,7))

colors = ['

bars1 = plt.bar(r1, accuracy, width=bar_width, color=colors[0], edgecolor='grey', label='Accuracy')
bars2 = plt.bar(r2, precision, width=bar_width, color=colors[1], edgecolor='grey', label='Precision')
bars3 = plt.bar(r3, recall, width=bar_width, color=colors[2], edgecolor='grey', label='Recall')
bars4 = plt.bar(r4, f1_score, width=bar_width, color=colors[3], edgecolor='grey', label='F1-Score')
bars5 = plt.bar(r5, roc_auc, width=bar_width, color=colors[4], edgecolor='grey', label='ROC AUC')

plt.xlabel('Models', fontweight='bold', fontsize=15)
plt.ylabel('Metrics (as fractions)', fontweight='bold', fontsize=15)
plt.xticks([r + 2*bar_width for r in range(len(accuracy))], models)

plt.legend(loc='upper right')

plt.tight_layout()
plt.savefig("experiment4_results_as_fractions.pdf")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

models = ['iForest', 'KMeans', 'Autoencoder', 'LSTM Autoencoder']
accuracy = np.array([73, 79, 63, 95])/ 100
precision = np.array([60, 80, 45, 93])/ 100
recall = np.array([59, 50, 44, 92])/ 100
f1_score = np.array([59, 61, 45, 92])/ 100
roc_auc = np.array([69.52, 71.84, 58.55, 93.02])/ 100 

bar_width = 0.12
r1 = np.arange(len(models))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]
r5 = [x + bar_width for x in r4]

plt.figure(figsize=(15,7))

colors = ['

bars1 = plt.bar(r1, accuracy, width=bar_width, color=colors[0], edgecolor='grey', label='Accuracy')
bars2 = plt.bar(r2, precision, width=bar_width, color=colors[1], edgecolor='grey', label='Precision')
bars3 = plt.bar(r3, recall, width=bar_width, color=colors[2], edgecolor='grey', label='Recall')
bars4 = plt.bar(r4, f1_score, width=bar_width, color=colors[3], edgecolor='grey', label='F1-Score')
bars5 = plt.bar(r5, roc_auc, width=bar_width, color=colors[4], edgecolor='grey', label='ROC AUC')

plt.xlabel('Models', fontweight='bold', fontsize=15)
plt.ylabel('Metrics (as fractions)', fontweight='bold', fontsize=15)
plt.xticks([r + 2*bar_width for r in range(len(accuracy))], models)

plt.legend(loc='upper left')

plt.tight_layout()
plt.savefig("experiment1_results_single_axis.pdf")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

models = ['iForest', 'KMeans', 'Autoencoder', 'LSTM Autoencoder']
accuracy = np.array([66, 79, 54, 68])/100
precision = np.array([49, 80, 31, 51])/100
recall =np.array([49, 49, 30, 51])/100
f1_score = np.array([49, 61, 30, 51])/100
roc_auc = np.array([61.85, 71.66, 47.89, 63.41])/100  

bar_width = 0.12
r1 = np.arange(len(models))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]
r5 = [x + bar_width for x in r4]

plt.figure(figsize=(15,7))

colors = ['

bars1 = plt.bar(r1, accuracy, width=bar_width, color=colors[0], edgecolor='grey', label='Accuracy')
bars2 = plt.bar(r2, precision, width=bar_width, color=colors[1], edgecolor='grey', label='Precision')
bars3 = plt.bar(r3, recall, width=bar_width, color=colors[2], edgecolor='grey', label='Recall')
bars4 = plt.bar(r4, f1_score, width=bar_width, color=colors[3], edgecolor='grey', label='F1-Score')
bars5 = plt.bar(r5, roc_auc, width=bar_width, color=colors[4], edgecolor='grey', label='ROC AUC')

plt.xlabel('Models', fontweight='bold', fontsize=15)
plt.ylabel('Metrics (as fractions)', fontweight='bold', fontsize=15)
plt.xticks([r + 2*bar_width for r in range(len(accuracy))], models)

plt.legend(loc='upper right')

plt.tight_layout()
plt.savefig("experiment3_results_single_axis.pdf")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

experiments = ['Experiment 1', 'Experiment 2', 'Experiment 3', 'Experiment 4']
roc_auc = np.array([93.02, 75.71, 71.66, 79.51])/100  
accuracy = np.array([95, 97, 79, 82])/100
precision = np.array([93, 54, 80, 74])/100
recall = np.array([92, 53, 49, 72])/100
f1_score = np.array([92, 53, 61, 73])/100
best_models = ['LSTM Autoencoder', 'iForest', 'KMeans', 'LSTM Autoencoder']

bar_width = 0.12
r1 = np.arange(len(experiments))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]
r5 = [x + bar_width for x in r4]

plt.figure(figsize=(15,7))

colors = ['

bars1 = plt.bar(r1, accuracy, width=bar_width, color=colors[0], edgecolor='grey', label='Accuracy')
bars2 = plt.bar(r2, precision, width=bar_width, color=colors[1], edgecolor='grey', label='Precision')
bars3 = plt.bar(r3, recall, width=bar_width, color=colors[2], edgecolor='grey', label='Recall')
bars4 = plt.bar(r4, f1_score, width=bar_width, color=colors[3], edgecolor='grey', label='F1-Score')
bars5 = plt.bar(r5, roc_auc, width=bar_width, color=colors[4], edgecolor='grey', label='ROC AUC')

plt.xlabel('Experiments', fontweight='bold', fontsize=15)
plt.ylabel('Metrics (as fractions)', fontweight='bold', fontsize=15)
plt.xticks([r + 2*bar_width for r in range(len(accuracy))], experiments)

for i, model in enumerate(best_models):
    plt.text(i + 2*bar_width, 0.05, f"Model: {model}", ha='center', color='black', fontsize=10) 

plt.legend(loc='upper right')

plt.tight_layout()
plt.savefig("experiment_comparison_single_axis.pdf")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

models = ['iForest', 'KMeans', 'Autoencoder', 'LSTM Autoencoder']

accuracy1 = np.array([73, 79, 63, 95])/ 100
precision1 = np.array([60, 80, 45, 93])/ 100
recall1 = np.array([59, 50, 44, 92])/ 100
f1_score1 = np.array([59, 61, 45, 92])/ 100
roc_auc1 = np.array([69.52, 71.84, 58.55, 93.02])/ 100

accuracy3 = np.array([66, 79, 54, 68])/100
precision3 = np.array([49, 80, 31, 51])/100
recall3 = np.array([49, 49, 30, 51])/100
f1_score3 = np.array([49, 61, 30, 51])/100
roc_auc3 = np.array([61.85, 71.66, 47.89, 63.41])/100

bar_width = 0.12
r1 = np.arange(len(models))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]
r5 = [x + bar_width for x in r4]

colors = ['

fig, axs = plt.subplots(1, 2, figsize=(30, 10))

axs[0].bar(r1, accuracy1, width=bar_width, color=colors[0], edgecolor='grey', label='Accuracy')
axs[0].bar(r2, precision1, width=bar_width, color=colors[1], edgecolor='grey', label='Precision')
axs[0].bar(r3, recall1, width=bar_width, color=colors[2], edgecolor='grey', label='Recall')
axs[0].bar(r4, f1_score1, width=bar_width, color=colors[3], edgecolor='grey', label='F1-Score')
axs[0].bar(r5, roc_auc1, width=bar_width, color=colors[4], edgecolor='grey', label='ROC AUC')
axs[0].set_title('Experiment 1')
axs[0].set_xlabel('Models')
axs[0].set_ylabel('Metrics (as fractions)')
axs[0].set_xticks([r + 2*bar_width for r in range(len(accuracy1))])
axs[0].set_xticklabels(models)
axs[0].legend(loc='upper left')

axs[1].bar(r1, accuracy3, width=bar_width, color=colors[0], edgecolor='grey', label='Accuracy')
axs[1].bar(r2, precision3, width=bar_width, color=colors[1], edgecolor='grey', label='Precision')
axs[1].bar(r3, recall3, width=bar_width, color=colors[2], edgecolor='grey', label='Recall')
axs[1].bar(r4, f1_score3, width=bar_width, color=colors[3], edgecolor='grey', label='F1-Score')
axs[1].bar(r5, roc_auc3, width=bar_width, color=colors[4], edgecolor='grey', label='ROC AUC')
axs[1].set_title('Experiment 3')
axs[1].set_xlabel('Models')
axs[1].set_ylabel('Metrics (as fractions)')
axs[1].set_xticks([r + 2*bar_width for r in range(len(accuracy3))])
axs[1].set_xticklabels(models)
axs[1].legend(loc='upper left')

plt.tight_layout()
plt.savefig("combined_experiment_results.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

models = ['iForest', 'KMeans', 'Autoencoder', 'LSTM Autoencoder']

accuracy1 = np.array([73, 79, 63, 95]) / 100
precision1 = np.array([60, 80, 45, 93]) / 100
recall1 = np.array([59, 50, 44, 92]) / 100
f1_score1 = np.array([59, 61, 45, 92]) / 100
roc_auc1 = np.array([69.52, 71.84, 58.55, 93.02]) / 100

accuracy4 = np.array([37, 82, 74, 82]) / 100
precision4 = np.array([35, 79, 62, 74]) / 100
recall4 = np.array([100, 65, 60, 72]) / 100
f1_score4 = np.array([52, 72, 61, 73]) / 100
roc_auc4 = np.array([0.5197, 0.7821, 0.7058, 0.7951])

bar_width = 0.12
r1 = np.arange(len(models))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]
r5 = [x + bar_width for x in r4]

colors = ['

fig, axs = plt.subplots(1, 2, figsize=(30, 10))

axs[0].bar(r1, accuracy1, width=bar_width, color=colors[0], edgecolor='grey', label='Accuracy')
axs[0].bar(r2, precision1, width=bar_width, color=colors[1], edgecolor='grey', label='Precision')
axs[0].bar(r3, recall1, width=bar_width, color=colors[2], edgecolor='grey', label='Recall')
axs[0].bar(r4, f1_score1, width=bar_width, color=colors[3], edgecolor='grey', label='F1-Score')
axs[0].bar(r5, roc_auc1, width=bar_width, color=colors[4], edgecolor='grey', label='ROC AUC')
axs[0].set_title('Experiment 1')
axs[0].set_xlabel('Models')
axs[0].set_ylabel('Metrics (as fractions)')
axs[0].set_xticks([r + 2*bar_width for r in range(len(accuracy1))])
axs[0].set_xticklabels(models)
axs[0].legend(loc='upper left')

axs[1].bar(r1, accuracy4, width=bar_width, color=colors[0], edgecolor='grey', label='Accuracy')
axs[1].bar(r2, precision4, width=bar_width, color=colors[1], edgecolor='grey', label='Precision')
axs[1].bar(r3, recall4, width=bar_width, color=colors[2], edgecolor='grey', label='Recall')
axs[1].bar(r4, f1_score4, width=bar_width, color=colors[3], edgecolor='grey', label='F1-Score')
axs[1].bar(r5, roc_auc4, width=bar_width, color=colors[4], edgecolor='grey', label='ROC AUC')
axs[1].set_title('Experiment 4')
axs[1].set_xlabel('Models')
axs[1].set_ylabel('Metrics (as fractions)')
axs[1].set_xticks([r + 2*bar_width for r in range(len(accuracy4))])
axs[1].set_xticklabels(models)
axs[1].legend(loc='upper left')

plt.tight_layout()
plt.savefig("combined_experiment1_and_experiment4_results.pdf")
plt.show()
